# %% [markdown]
# # 1
# 컴퓨터 프로그램이란
# -> 컴퓨터가 목표에 도달하기 위해 따라야하는 명령어 목록
#
# # 2
# 언어의 구문이란
# -> 해당 언어로 사물을 표현하는 방법의 규칙
#
# # 3
# 프로그램과 스크립트의 차이
# -> 본질적으로 큰 차이는 없지만 스크립트는 일반적으로 더 간단하고 짧습니다.
#
# # 4
# 다음중 자동화에 적합한 시나리오는?
# -> 지역, 회사, 웹사이트
#
# # 5
# 프로그래밍 코드와 의사코드에 적용될 때 의미는 무엇입니까?
# -> 프로그래밍 명령어가 미치는 영향
